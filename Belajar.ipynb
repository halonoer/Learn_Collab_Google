# %% [markdown]
# <a href="https://colab.research.google.com/github/halonoer/Learn_Collab_Google/blob/main/Belajar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This *is* **heading**

# %% [markdown]
# [Google Search](https://www.google.com)

# %% [markdown]
# Hello
# 1.   First
# 2.   Second
# ---
# haha
# *   First
# *   Second
# ---
# man
# > first
#
# > Second
# ---
#
# $ ax^2 + bx + c = 0 $
#
# ---
#
#
# $x1 = \frac{-b + \sqrt(b^2) - 4ac }{4ac} $

# %% [markdown]
# ![(edit)foto baju hijau 2.jpg](data:image/jpeg;base64,...)
